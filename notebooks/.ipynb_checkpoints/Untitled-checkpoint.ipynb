# %%
# !pip install yfinance pandas numpy
# Out:
# Requirement already satisfied: yfinance in d:\shivam\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas in d:\shivam\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in d:\shivam\lib\site-packages (1.24.3)
# Requirement already satisfied: requests>=2.31 in d:\shivam\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in d:\shivam\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\shivam\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in d:\shivam\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in d:\shivam\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in d:\shivam\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\shivam\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.7 in d:\shivam\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in d:\shivam\lib\site-packages (from yfinance) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in d:\shivam\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\shivam\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\shivam\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\shivam\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\shivam\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.7.1)
# Requirement already satisfied: cffi>=1.12.0 in d:\shivam\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.15.1)
# Requirement already satisfied: certifi>=2024.2.2 in d:\shivam\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: six>=1.5 in d:\shivam\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\shivam\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\shivam\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\shivam\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: pycparser in d:\shivam\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)

# %%
import pandas as pd
import yfinance as yf
import os

# %%
tickers = ["TSLA", "AMZN", "NVDA", "MSFT", "GOOG"]

# %%
os.makedirs("../data/raw", exist_ok=True)

for ticker in tickers:
    print(f"Downloading {ticker}...")
    df = yf.download(ticker, period="10y", interval="1d")
    df.reset_index(inplace=True)
    df.to_csv(f"../data/raw/{ticker}.csv", index=False)
    print(f"Saved {ticker}.csv")
# Out:
# Downloading TSLA...
# C:\Users\Sangam\AppData\Local\Temp\ipykernel_8940\3095866388.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="10y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Sangam\AppData\Local\Temp\ipykernel_8940\3095866388.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="10y", interval="1d")
# Saved TSLA.csv
# Downloading AMZN...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Sangam\AppData\Local\Temp\ipykernel_8940\3095866388.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="10y", interval="1d")
# Saved AMZN.csv
# Downloading NVDA...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Sangam\AppData\Local\Temp\ipykernel_8940\3095866388.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="10y", interval="1d")
# Saved NVDA.csv
# Downloading MSFT...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Sangam\AppData\Local\Temp\ipykernel_8940\3095866388.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="10y", interval="1d")
# Saved MSFT.csv
# Downloading GOOG...
# [*********************100%***********************]  1 of 1 completed
# Saved GOOG.csv

# %%
df = pd.read_csv("../data/raw/TSLA.csv")
df.head()
# Out:
#          Date               Close                High                 Low  \
# 0         NaN                TSLA                TSLA                TSLA
# 1  2015-12-07  15.408666610717773  15.708666801452637  15.076666831970215
# 2  2015-12-08  15.114666938781738   15.25333309173584  14.946666717529297
# 3  2015-12-09  14.968000411987305  15.166666984558105  14.714667320251465
# 4  2015-12-10  15.137999534606934  15.232666969299316  14.909333229064941
#
#                  Open    Volume
# 0                TSLA      TSLA
# 1  15.180000305175781  47163000
# 2  15.168000221252441  40314000
# 3  15.113332748413086  45867000
# 4  14.980667114257812  31075500

# %%
for ticker in tickers:
    df = pd.read_csv(f"../data/raw/{ticker}.csv")
    print(ticker, df.shape)
# Out:
# TSLA (2516, 6)
# AMZN (2516, 6)
# NVDA (2516, 6)
# MSFT (2516, 6)
# GOOG (2516, 6)
